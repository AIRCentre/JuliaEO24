# %% [markdown]
# # Speckle
#  <a class="anchor" id="speckle"></a>

# %% [markdown]
# The Sentinel-1 satellite has a spatial pixel resolution of approx 3.1 m x 21.7 m. However, in each pixel, there are very many individual scatters. Each of these individual scatters contributate with their own individual amplitude and phase
#
# $ A exp(j \phi)  = \sum_i A_i exp(j \phi_i) $
#
# where $A$ is the Amplitude of the signal and $\phi$ the phase.

# %% [markdown]
# ![CFAR windows](figures/speckle.png "CFAR windows" )

# %% [markdown]
# The wavelength of the SAR is much smaller than the resolution cell and the distance between the individual scatters and the phase therefore varies greatly. In fact:
# - The phase varies approximatly uniform in [$-\pi : \pi$]
# - The phase is independant of A
# - The Amplitude is uncorrelated

# %% [markdown]
# ![CFAR windows](figures/speckle_illustration.png "CFAR windows" )

# %% [markdown]
# The Speckle noise is multiplicative, i.e.
#
# $z = x*f $
#
# where $z$ is the measured pixel, $x$ the speckle-free pixel and $f$ the speckle.

# %% [markdown]
# ### Speckle Reduction

# %% [markdown]
# We would like to reduce this "noise" such that we can approximate the true backscatter, $x$.

# %% [markdown]
# The objective of speckle reduction is to reduce the variance of the pixels such that a better estimate of the intensity is found. The trade-off is a poorer spatial resolution. There exsits very many speckle filters that all tries to reduce this black-white granularity. The following introduces:
# - Mean filter
#
# The mean filter is a simple filter that simply assign the mean value of a region to a center pixel.
#
# The Lee filter is an adaptive filter, that varies the degree of speckle filtering depending on the homogenity of the region. For very homogenous regions, it resembles the Mean filter. However, close to, e.g., edges or in very inhomogenous region the speckle filtering reduces.

# %% [markdown]
# #### Homogenous region

# %%
sar2gray(grd_image_hom, p_quantile = 0.99999)
# Out:
# 301×301 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.430579)  Gray{Float64}(0.450151)  …  Gray{Float64}(0.371864)
#  Gray{Float64}(0.528438)  Gray{Float64}(0.469722)     Gray{Float64}(0.33272)
#  Gray{Float64}(0.606725)  Gray{Float64}(0.450151)     Gray{Float64}(0.587153)
#  Gray{Float64}(0.54801)   Gray{Float64}(0.489294)     Gray{Float64}(0.704584)
#  Gray{Float64}(0.371864)  Gray{Float64}(0.352292)     Gray{Float64}(0.567581)
#  Gray{Float64}(0.352292)  Gray{Float64}(0.313148)  …  Gray{Float64}(0.411007)
#  Gray{Float64}(0.352292)  Gray{Float64}(0.391435)     Gray{Float64}(0.430579)
#  Gray{Float64}(0.626297)  Gray{Float64}(0.371864)     Gray{Float64}(0.528438)
#  Gray{Float64}(0.626297)  Gray{Float64}(0.313148)     Gray{Float64}(0.352292)
#  Gray{Float64}(0.352292)  Gray{Float64}(0.313148)     Gray{Float64}(0.489294)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.254433)  Gray{Float64}(0.195718)     Gray{Float64}(0.430579)
#  Gray{Float64}(0.371864)  Gray{Float64}(0.215289)     Gray{Float64}(0.430579)
#  Gray{Float64}(0.587153)  Gray{Float64}(0.411007)     Gray{Float64}(0.469722)
#  Gray{Float64}(0.528438)  Gray{Float64}(0.587153)  …  Gray{Float64}(0.411007)
#  Gray{Float64}(0.371864)  Gray{Float64}(0.508866)     Gray{Float64}(0.371864)
#  Gray{Float64}(0.411007)  Gray{Float64}(0.371864)     Gray{Float64}(0.391435)
#  Gray{Float64}(0.274005)  Gray{Float64}(0.313148)     Gray{Float64}(0.411007)
#  Gray{Float64}(0.391435)  Gray{Float64}(0.293577)     Gray{Float64}(0.450151)
#  Gray{Float64}(0.626297)  Gray{Float64}(0.430579)  …  Gray{Float64}(0.54801)

# %%
hom_descpek_mean_9 =speckle_mean_filter(grd_image_hom.^2,[9,9]);
sar2gray(hom_descpek_mean_9, p_quantile = 0.95)
# Out:
# 293×293 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.703907)  Gray{Float64}(0.626269)  …  Gray{Float64}(0.859004)
#  Gray{Float64}(0.746843)  Gray{Float64}(0.681506)     Gray{Float64}(0.958762)
#  Gray{Float64}(0.806683)  Gray{Float64}(0.7494)       Gray{Float64}(1.10156)
#  Gray{Float64}(0.878516)  Gray{Float64}(0.825785)     Gray{Float64}(1.14784)
#  Gray{Float64}(0.983593)  Gray{Float64}(0.943853)     Gray{Float64}(1.16889)
#  Gray{Float64}(1.07844)   Gray{Float64}(1.04218)   …  Gray{Float64}(1.15073)
#  Gray{Float64}(1.06816)   Gray{Float64}(1.03359)      Gray{Float64}(1.12248)
#  Gray{Float64}(0.978657)  Gray{Float64}(0.9504)       Gray{Float64}(1.04394)
#  Gray{Float64}(0.878234)  Gray{Float64}(0.892401)     Gray{Float64}(0.977148)
#  Gray{Float64}(0.795738)  Gray{Float64}(0.849389)     Gray{Float64}(1.01228)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.161413)  Gray{Float64}(0.175018)     Gray{Float64}(0.605018)
#  Gray{Float64}(0.17824)   Gray{Float64}(0.20637)   …  Gray{Float64}(0.559193)
#  Gray{Float64}(0.307074)  Gray{Float64}(0.337991)     Gray{Float64}(0.514211)
#  Gray{Float64}(0.434143)  Gray{Float64}(0.447876)     Gray{Float64}(0.545)
#  Gray{Float64}(0.476696)  Gray{Float64}(0.459639)     Gray{Float64}(0.539374)
#  Gray{Float64}(0.496438)  Gray{Float64}(0.45322)      Gray{Float64}(0.515387)
#  Gray{Float64}(0.580162)  Gray{Float64}(0.556559)  …  Gray{Float64}(0.51976)
#  Gray{Float64}(0.755487)  Gray{Float64}(0.774717)     Gray{Float64}(0.572234)
#  Gray{Float64}(0.894012)  Gray{Float64}(0.925006)     Gray{Float64}(0.686518)

# %%
histogram(vcat(speckle_mean_filter(grd_image_hom.^2,[27,27])...),label="Mean filter [27x27]", alpha = 0.2)
histogram!(vcat(speckle_mean_filter(grd_image_hom.^2,[19,19])...),label="Mean filter [19x19]", alpha = 0.2)
histogram!(vcat(speckle_mean_filter(grd_image_hom.^2,[13,13])...),label="Mean filter [13x13]", alpha = 0.2)
histogram!(vcat(speckle_mean_filter(grd_image_hom.^2,[5,5])...),label="Mean filter [5x5]", alpha = 0.2)

xlabel!("Intensity pixel value")
ylabel!("Number of pixels")

# %% [markdown]
# We see that the Mean filter, and in fact many speckle filters, changes the distribution to a Gaussian distribution. With increasing filter sizes, we reduce the variance.

# %% [markdown]
# #### Inhomogenous region

# %%
sar2gray(slc_image[200:600,:], p_quantile = 0.96)
# Out:
# 401×1401 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.206977)   …  Gray{Float64}(0.410618)
#  Gray{Float64}(0.154287)      Gray{Float64}(0.653039)
#  Gray{Float64}(0.294393)      Gray{Float64}(1.4419)
#  Gray{Float64}(0.478696)      Gray{Float64}(1.99085)
#  Gray{Float64}(0.437618)      Gray{Float64}(1.00909)
#  Gray{Float64}(0.578181)   …  Gray{Float64}(0.384573)
#  Gray{Float64}(0.147888)      Gray{Float64}(0.560061)
#  Gray{Float64}(0.359093)      Gray{Float64}(0.856603)
#  Gray{Float64}(0.286177)      Gray{Float64}(0.727223)
#  Gray{Float64}(0.245704)      Gray{Float64}(0.164399)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.232495)      Gray{Float64}(0.0618399)
#  Gray{Float64}(0.0954425)     Gray{Float64}(0.027027)
#  Gray{Float64}(0.0414576)     Gray{Float64}(0.0262201)
#  Gray{Float64}(0.0621864)  …  Gray{Float64}(0.0655502)
#  Gray{Float64}(0.0974473)     Gray{Float64}(0.0236344)
#  Gray{Float64}(0.0821341)     Gray{Float64}(0.0658771)
#  Gray{Float64}(0.0563884)     Gray{Float64}(0.0604343)
#  Gray{Float64}(0.112204)      Gray{Float64}(0.0821341)
#  Gray{Float64}(0.143912)   …  Gray{Float64}(0.0262201)

# %%
descpek_mean_9 = speckle_mean_filter(slc_image,[11,11]);
sar2gray(descpek_mean_9, p_quantile = 0.95)
# Out:
# 591×1391 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.478898)   …  Gray{Float64}(0.578052)
#  Gray{Float64}(0.485029)      Gray{Float64}(0.574196)
#  Gray{Float64}(0.488744)      Gray{Float64}(0.578986)
#  Gray{Float64}(0.478017)      Gray{Float64}(0.559365)
#  Gray{Float64}(0.499483)      Gray{Float64}(0.538697)
#  Gray{Float64}(0.503243)   …  Gray{Float64}(0.529351)
#  Gray{Float64}(0.474364)      Gray{Float64}(0.52178)
#  Gray{Float64}(0.463059)      Gray{Float64}(0.533758)
#  Gray{Float64}(0.464058)      Gray{Float64}(0.559011)
#  Gray{Float64}(0.476343)      Gray{Float64}(0.598361)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.0692488)     Gray{Float64}(0.0255001)
#  Gray{Float64}(0.062593)      Gray{Float64}(0.0251653)
#  Gray{Float64}(0.0599237)     Gray{Float64}(0.029875)
#  Gray{Float64}(0.058773)   …  Gray{Float64}(0.0264781)
#  Gray{Float64}(0.0541808)     Gray{Float64}(0.0250514)
#  Gray{Float64}(0.0535339)     Gray{Float64}(0.0257858)
#  Gray{Float64}(0.0469289)     Gray{Float64}(0.0222498)
#  Gray{Float64}(0.0460606)     Gray{Float64}(0.0231577)
#  Gray{Float64}(0.0457639)  …  Gray{Float64}(0.0180176)

# %% [markdown]
# We see that the mean filter filters much of the noise in the ocean. However, we lose a lot of spatial content, e.g., near the shore or in the city.

# %% [markdown]
# **Question**:
# - Try to use the Lee filter with a filter size of [9,9] to filter the image.
# - Are the results better? Why is that?
#
# (hint: Look at the SARProcessing.speckle_lee_filter function)
